# %%
################### user inputs ###############################
repo_folder = '.'


## filenames
master_input_filename = 'main_inputs'





###############################################################
import os
os.chdir(repo_folder)
# import importlib

from pondit.load_data import *
from pondit.calc_ET import *
from pondit.calc_model import *
from pondit.plot_model import *

import pandas
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

# %matplotlib inline

folder_in = repo_folder + '/inputs/'
folder_out = repo_folder + '/results/'

### load input data common to all sites
scalars = pandas.read_csv(folder_in + master_input_filename + '.csv', index_col=0)

site_list = scalars.index
site_list = scalars.loc[scalars['status'] != 'done', :].index


for site in site_list:
    sws_calc_dict = {}
    print(site)
    ## load data
    stage_storage, soils, data_hist, last_hist_date, calib_data = load_data(scalars, site, folder_in)

    
    bc_calc = calc_ET(data_hist, scalars, site, repo_folder)

    sws_calc, out, scalars_out = calc_pondit(bc_calc, scalars, site, stage_storage, soils, repo_folder, calib_data)
    sws_calc.to_csv(folder_out + '/data/'+ site + '_data_hist.csv')
    scalars_out.to_csv(folder_out + 'data/' + site + '_model_params_hist.csv')
    plot_model(sws_calc, scalars, site, folder_out)
# Out:
# <style>.container { width:95% !important; }</style>
# Pond3
# Blaney Criddle fit parameters: a =  1.33552219751  b =  -5.38245185504
# [ 0.05  0.05  2.    1.5   0.1   0.01  0.5   0.7 ] sum squared error:  1.04728944669
# [ 0.05  0.05  2.    1.5   0.1   0.01  0.5   0.7 ] sum squared error:  1.04728944669
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4bee2fe9fe2a> in <module>()
#      46     bc_calc = calc_ET(data_hist, scalars, site, repo_folder)
#      47
# ---> 48     sws_calc, out, scalars_out = calc_pondit(bc_calc, scalars, site, stage_storage, soils, repo_folder, calib_data)
#      49     sws_calc.to_csv(folder_out + '/data/'+ site + '_data_hist.csv')
#      50     scalars_out.to_csv(folder_out + 'data/' + site + '_model_params_hist.csv')
#
# /P/2018/218136 GCRCD Pond Model Development/Python/python_repo/pondit/calc_model.py in calc_pondit(bc_calc, scalars, site, stage_storage, soils, repo_folder, calib_data)
#      62
#      63     ## minimize residuals
# ---> 64     out = scipy.optimize.minimize(residuals, p0, method='SLSQP', bounds=bounds, options={'disp':True, 'eps':0.1, 'ftol':0.00001})
#      65     print(out) ## print final result
#      66
#
# /opt/conda/lib/python3.5/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     456     elif meth == 'slsqp':
#     457         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 458                                constraints, callback=callback, **options)
#     459     elif meth == 'dogleg':
#     460         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# /opt/conda/lib/python3.5/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     388             # Compute the derivatives of the objective function
#     389             # For some reason SLSQP wants g dimensioned to n+1
# --> 390             g = append(fprime(x),0.0)
#     391
#     392             # Compute the normals of the constraints
#
# /opt/conda/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /opt/conda/lib/python3.5/site-packages/scipy/optimize/slsqp.py in approx_jacobian(x, func, epsilon, *args)
#      61     for i in range(len(x0)):
#      62         dx[i] = epsilon
# ---> 63         jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#      64         dx[i] = 0.0
#      65
#
# /opt/conda/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /P/2018/218136 GCRCD Pond Model Development/Python/python_repo/pondit/calc_model.py in residuals(params_model)
#      48     def residuals(params_model):
#      49         import numpy as np
# ---> 50         return np.power(y-fitfunc(params_model, params_to_fit, scalars, bc_calc_model, soils), 2).sum()
#      51
#      52     ## calibration data
#
# /P/2018/218136 GCRCD Pond Model Development/Python/python_repo/pondit/calc_model.py in fitfunc(params_model, params_to_fit, scalars, bc_calc_model, soils)
#      43     ## define function to fit model
#      44     def fitfunc(params_model, params_to_fit, scalars, bc_calc_model, soils): # model
# ---> 45         y = pondit_calib(params_model, params_to_fit, scalars, bc_calc_model, soils, calib_data, site, stage_storage)
#      46         return y
#      47     ## define function to calculate residuals to minimize
#
# /P/2018/218136 GCRCD Pond Model Development/Python/python_repo/pondit/calc_model.py in pondit_calib(params_model, params_to_fit, scalars, bc_calc_model, soils, calib_data, site, stage_storage)
#      81     import numpy as np
#      82
# ---> 83     sws_calc = pondit_output(params_model, params_to_fit, scalars, bc_calc_model, soils, site, stage_storage)
#      84
#      85
#
# /P/2018/218136 GCRCD Pond Model Development/Python/python_repo/pondit/calc_model.py in pondit_output(params_model, params_to_fit, scalars, bc_calc, soils, site, stage_storage)
#     245         ## calculate all outputs: use last months ET to calculate pond volume
#     246         ## this is because pond area is needed to calculate ET, which need pond volume, so either use last months pond area, or last months et; chose the latter
# --> 247         sws_calc.loc[n, 'outs'] = sws_calc.loc[n, 'gw_out_bottom'] + sws_calc.loc[n-1, 'pond_et'] + sws_calc.loc[n, 'gw_out_et']
#     248
#     249         ##update pond volume: previous months volume + inputs - outputs
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1308
#    1309         if type(key) is tuple:
# -> 1310             return self._getitem_tuple(key)
#    1311         else:
#    1312             return self._getitem_axis(key, axis=0)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     794     def _getitem_tuple(self, tup):
#     795         try:
# --> 796             return self._getitem_lowerdim(tup)
#     797         except IndexingError:
#     798             pass
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     920         for i, key in enumerate(tup):
#     921             if is_label_like(key) or isinstance(key, tuple):
# --> 922                 section = self._getitem_axis(key, axis=i)
#     923
#     924                 # we have yielded a scalar ?
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1481         # fall thru to straight lookup
#    1482         self._has_valid_type(key, axis)
# -> 1483         return self._get_label(key, axis=axis)
#    1484
#    1485
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     100             raise IndexingError('no slices here, handle elsewhere')
#     101
# --> 102         return self.obj._xs(label, axis=axis)
#     103
#     104     def _get_loc(self, key, axis=0):
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    1802             result = self._constructor_sliced(
#    1803                 new_values, index=self.columns,
# -> 1804                 name=self.index[loc], dtype=new_values.dtype)
#    1805
#    1806         else:
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     243                                        raise_cast_failure=True)
#     244
# --> 245                 data = SingleBlockManager(data, index, fastpath=True)
#     246
#     247         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4068         if not isinstance(block, Block):
#    4069             block = make_block(block, placement=slice(0, len(axis)), ndim=1,
# -> 4070                                fastpath=True)
#    4071
#    4072         self.blocks = [block]
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2663               not issubclass(vtype, np.datetime64)):
#    2664             klass = IntBlock
# -> 2665         elif dtype == np.bool_:
#    2666             klass = BoolBlock
#    2667         elif issubclass(vtype, np.datetime64):
#
# KeyboardInterrupt:
